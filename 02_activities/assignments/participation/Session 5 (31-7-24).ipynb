# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# %%
tips = sns.load_dataset("tips")
print(tips)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.set_style('whitegrid')
sns.lineplot(data = tips,
             x = 'total_bill',
             y = 'tip' )
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
tipgraph = sns.lineplot(data = tips,
                        x = 'total_bill',
                        y = 'tip')
tipgraph.set(title = 'Tips vs Total Bill',
             xlabel = 'Total Bill ($)',
             ylabel = 'Tips Amount ($)')
# Out:
# [Text(0.5, 1.0, 'Tips vs Total Bill'),
#  Text(0.5, 0, 'Total Bill ($)'),
#  Text(0, 0.5, 'Tips Amount ($)')]

# %%
fig = plt.subplots(figsize=(10,3))

tipgraph = sns.lineplot(data = tips,
                        x = 'total_bill',
                        y = 'tip',
                        color = 'hotpink',
                        linestyle = '--',
                        linewidth = 3,
                        marker = 'o',
                        markerfacecolor = 'indigo')
tipgraph.set(title = 'Tips vs Total Bill',
             xlabel = 'Total Bill ($)',
             ylabel = 'Tips Amount ($)')
# Out:
# [Text(0.5, 1.0, 'Tips vs Total Bill'),
#  Text(0.5, 0, 'Total Bill ($)'),
#  Text(0, 0.5, 'Tips Amount ($)')]

# %%
tipgraph = sns.scatterplot(data = tips,
                           x = 'total_bill',
                           y = 'tip',
                           style = 'time',
                           hue = 'day',
                           palette = ['purple',
                                      'hotpink',
                                      'deepskyblue',
                                      'yellowgreen'])
tipgraph.set(title = 'Tips vs Total Bill',
             xlabel = 'Total Bill ($)',
             ylabel = 'Tips Amount ($)')
# Out:
# [Text(0.5, 1.0, 'Tips vs Total Bill'),
#  Text(0.5, 0, 'Total Bill ($)'),
#  Text(0, 0.5, 'Tips Amount ($)')]

# %%
sns.pairplot(data = tips,
             hue = 'day')

# %%
sns.relplot(data = tips,
            x = "total_bill",
            y = "tip",
            hue = "sex",
            col = "day",
            kind = "scatter",
            col_wrap = 2)

# %%
import plotly.graph_objects as go 

x1 = np.array (["luffy","zoro", "nami", "usopp", "sanji"])
y1 = np.array([110,180,240,99,220])

# %%
graph = go.Figure()

graph.add_trace(go.Bar( x= x1, y=y1))

graph.update_layout(title = "Pirate Scores",
                    xaxis_title = "Pirates",
                    yaxis_title = "Score")

# %%
graph = go.Figure()

graph.add_trace(go.Scatter(
    x= x1,
    y= y1,
    mode = 'markers',
    marker = dict(
        size = 15,
        color = 'hotpink',
        opacity = 1,
        line = dict(width = 5, color = 'purple')
    )
))

graph.update_layout(
    title = 'Interactive Pirate Plot',
    xaxis_title = 'Pirates',
    yaxis_title = 'Scores',
    width = 500,
    height = 500
)

# %%
# !pip install wordcloud
from wordcloud import WordCloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.3-cp39-cp39-macosx_11_0_arm64.whl.metadata (3.4 kB)
# Requirement already satisfied: numpy>=1.6.1 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from wordcloud) (1.24.4)
# Requirement already satisfied: pillow in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from wordcloud) (10.3.0)
# Requirement already satisfied: matplotlib in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from wordcloud) (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from matplotlib->wordcloud) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from matplotlib->wordcloud) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from matplotlib->wordcloud) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from matplotlib->wordcloud) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from matplotlib->wordcloud) (2.9.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from matplotlib->wordcloud) (6.4.0)
# Requirement already satisfied: zipp>=3.1.0 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->wordcloud) (3.17.0)
# Requirement already satisfied: six>=1.5 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Downloading wordcloud-1.9.3-cp39-cp39-macosx_11_0_arm64.whl (168 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.0/169.0 kB 4.0 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.3

# %%
from wordcloud import WordCloud
df = pd.read_csv("https://raw.githubusercontent.com/prasertcbs/basic-dataset/master/movie_quotes.csv",
on_bad_lines='skip')
df
# Out:
#                                                  quote  \
# 0                      Do, or do not. There is no try.
# 1    Listen to them. Children of the night. What mu...
# 2                              It's alive! It's alive!
# 3    Oh, no, it wasn't the airplanes. It was Beauty...
# 4    Magic Mirror on the wall, who is the fairest o...
# ..                                                 ...
# 727  I didn't know if you were lost. Stick with me....
# 728  This guy's awesome! He's holding his own while...
# 729     Murder is murder, it don’t matter who you are.
# 730  You know what a lion is? A lion is a strong an...
# 731  That was the best acting i've ever seen in my ...
#
#                                               movie   type  year
# 0    Star Wars: Episode V - The Empire Strikes Back  movie  1890
# 1                                           Dracula  movie  1931
# 2                                      Frankenstein  movie  1931
# 3                                         King Kong  movie  1933
# 4                  Snow White and the Seven Dwarves  movie  1937
# ..                                              ...    ...   ...
# 727                                              Us  movie  2019
# 728                        Dragon Ball Super: Broly  movie  2019
# 729                                  Black and Blue  movie  2019
# 730                    Between Two Ferns: The Movie  movie  2019
# 731                   Once Upon a Time in Hollywood  movie  2019
#
# [732 rows x 4 columns]

# %%
# join all our text from each row from our quote column into a string
text = " ".join(each for each in df.quote)
# generate our wordcloud image
wordcloud = WordCloud(background_color="white",
colormap = 'inferno').generate(text)
# use matplotlib syntax to put our image in a figure
fig, ax = plt.subplots(figsize=(7, 3))
ax.imshow(wordcloud, # remember 'imshow' from when we added pictures to our matplotlib axes
interpolation='bilinear') # this line helps smooth our image
ax.axis("off")
plt.show()

# %%
# !pip install matplotlib-venn
from matplotlib_venn import venn2, venn2_circles, venn2_unweighted
# Out:
# Collecting matplotlib-venn
#   Using cached matplotlib-venn-1.1.1.tar.gz (40 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: matplotlib in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from matplotlib-venn) (3.8.4)
# Requirement already satisfied: numpy in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from matplotlib-venn) (1.24.4)
# Requirement already satisfied: scipy in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from matplotlib-venn) (1.13.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from matplotlib->matplotlib-venn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from matplotlib->matplotlib-venn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from matplotlib->matplotlib-venn) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from matplotlib->matplotlib-venn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from matplotlib->matplotlib-venn) (24.0)
# Requirement already satisfied: pillow>=8 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from matplotlib->matplotlib-venn) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from matplotlib->matplotlib-venn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from matplotlib->matplotlib-venn) (2.9.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from matplotlib->matplotlib-venn) (6.4.0)
# Requirement already satisfied: zipp>=3.1.0 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->matplotlib-venn) (3.17.0)
# Requirement already satisfied: six>=1.5 in /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->matplotlib-venn) (1.16.0)
# Building wheels for collected packages: matplotlib-venn
#   Building wheel for matplotlib-venn (pyproject.toml) ... done
#   Created wheel for matplotlib-venn: filename=matplotlib_venn-1.1.1-py3-none-any.whl size=45286 sha256=06dce2d640d9db72f05a01f559901ac34484041fc2215e9ac7e32e3208b1dd49
#   Stored in directory: /Users/namraschazil/Library/Caches/pip/wheels/5c/4b/48/d68a6531b1e1e7411520ab9f395994eb1ee2ffafd6837b7f6c
# Successfully built matplotlib-venn
# Installing collected packages: matplotlib-venn
# Successfully installed matplotlib-venn-1.1.1

# %%
A = set (["apple", "banana", "watermelon"])
B = set(["pumpkin", "blueberry", "apple", "key lime"])
diagram = venn2([A,B],
                set_labels = ("Fruits", "Pies"),
                set_colors = ("blue", "red"),
                alpha = 0.5)

diagram.get_label_by_id("10").set_text("n".join(A - B))
diagram.get_label_by_id("11").set_text("n".join(A & B))
diagram.get_label_by_id("01").set_text("n".join(B - A))
